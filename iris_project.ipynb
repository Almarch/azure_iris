# %% [markdown]
# # Set-up the client

# %%
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential
from azure.ai.ml import MLClient

try:
    credential = DefaultAzureCredential()
    # Check if given credential can get token successfully.
    credential.get_token("https://management.azure.com/.default")
except Exception as ex:
    # Fall back to InteractiveBrowserCredential in case DefaultAzureCredential not work
    credential = InteractiveBrowserCredential()

# Get a handle to workspace
ml_client = MLClient.from_config(credential=credential)

# Retrieve an already attached Azure Machine Learning Compute.
cluster_name = "myCluster"
print(ml_client.compute.get(cluster_name))

# %% [markdown]
# # Data asset

# %% [markdown]
# ### Iris dataset

# %%
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes
from datetime import datetime

iris_data = Data(
    path="./data",
    type=AssetTypes.MLTABLE,
    description="Fisher's iris dataset",
    name="iris",
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)

ml_client.data.create_or_update(iris_data)

# %%
import mltable

data_asset = ml_client.data.get("iris", label="latest")

tbl = mltable.load(data_asset.path)

df = tbl.to_pandas_dataframe()
df.head()

# %% [markdown]
# ### Model architecture

# %%
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes
from datetime import datetime

model_asset = Data(
    name="iris_model_architecture",
    path="./iris_model/iris_model.py",
    type=AssetTypes.URI_FILE,
    description="Architecture definition for Iris classifier",
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)
ml_client.data.create_or_update(model_asset)

# %% [markdown]
# # Environments

# %% [markdown]
# ## Train environment

# %%
from azure.ai.ml.entities import Environment, BuildContext
from datetime import datetime

env = Environment(
    name="iris_train",
    description="PyTorch CPU training environment",
    build=BuildContext(
        path = "./environments/iris_train/",
        dockerfile_path="Dockerfile"
    ),
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)

ml_client.environments.create_or_update(env)

# %%
env_check = ml_client.environments.get(
    name="iris_train",
    label = "latest"
)

print(f"✅ Environment exists: {env_check.name} v{env_check.version}")
print(f"Image URI: {env_check.image}")  # Vide si build en cours

# %% [markdown]
# ## Unit test environment

# %%
# !docker build -t iris-train:latest -f environments/iris_train/Dockerfile environments/iris_train
# !docker build -t iris-tests:latest -f environments/iris_tests/Dockerfile environments/iris_tests

# %% [markdown]
# # Unit tests

# %%
pass

# %% [markdown]
# # Components

# %%
from azure.ai.ml import load_component
from datetime import datetime

components_dir = "./components/"

data_prepare_component = load_component(source=f"{components_dir}/data_prepare/data_prepare.yaml")
ml_client.components.create_or_update(
    data_prepare_component,
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)
print("✅ data_prepare registred")

data_split_component = load_component(source=f"{components_dir}/data_split/data_split.yaml")
ml_client.components.create_or_update(
    data_split_component,
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)
print("✅ data_split registred")

model_train_component = load_component(source=f"{components_dir}/model_train/model_train.yaml")
ml_client.components.create_or_update(
    model_train_component,
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)
print("✅ model_train registred")

model_eval_component = load_component(source=f"{components_dir}/model_eval/model_eval.yaml")
ml_client.components.create_or_update(
    model_eval_component,
    version = datetime.now().strftime("%Y%m%d%H%M%S"),
)
print("✅ model_eval registred")

# %% [markdown]
# # Pipelines as components

# %%
from pipelines.evaluation import iris_evaluation_pipeline
from datetime import datetime

registered_eval_pipeline = ml_client.components.create_or_update(
    iris_evaluation_pipeline,
    version=datetime.now().strftime("%Y%m%d%H%M%S"),
)

print(f"    Name: {registered_eval_pipeline.name}")
print(f"    Version: {registered_eval_pipeline.version}")

# %%
from pipelines.production import iris_production_pipeline
from datetime import datetime

registered_prod_pipeline = ml_client.components.create_or_update(
    iris_production_pipeline,
    version=datetime.now().strftime("%Y%m%d%H%M%S"),
)

print(f"    Name: {registered_prod_pipeline.name}")
print(f"    Version: {registered_prod_pipeline.version}")

# %% [markdown]
# # Production job

# %%
from pipelines.production import iris_production_pipeline
from azure.ai.ml import Input
from azure.ai.ml.constants import AssetTypes

data_asset = ml_client.data.get("iris", label="latest")
model_asset = ml_client.data.get("iris_model_architecture", label="latest")

data_input = Input(
    type=AssetTypes.MLTABLE,
    path=data_asset.id,
)

model_input = Input(
    type=AssetTypes.URI_FILE,
    path=model_asset.id,
)

production_job = iris_production_pipeline(
    data=data_input,
    archi=model_input,
    compute="myCluster",
)

submitted_job = ml_client.jobs.create_or_update(
    production_job,
    experiment_name="iris-classification"
)

print(f"✅ Production pipeline submitted!")
print(f"   Job name: {submitted_job.name}")
print(f"   Studio URL: {submitted_job.studio_url}")

# Optionnel : real time job monitoring
# ml_client.jobs.stream(submitted_job.name)

# %% [markdown]
# ## Recurrent execution

# %%
# Get the job to schedule

all_jobs = ml_client.jobs.list()
jobs_list = [
    job for job in ml_client.jobs.list() 
    if job.experiment_name == "iris-classification" 
    and job.properties.get("runSource") != "Schedule"
]
job = jobs_list[0]
job

# %%
from azure.ai.ml.entities import JobSchedule, RecurrenceTrigger

job =  ml_client.jobs.get(name = "frank_airport_nl42g9wj33")

schedule = JobSchedule(
    name="iris-daily-retrain",
    trigger=RecurrenceTrigger(
        frequency="hour",  # or "day", "week", "month"
        interval=1
    ),
    create_job=job.name
)

ml_client.schedules.begin_create_or_update(schedule=schedule)

# %% [markdown]
# ## Custom parameters

# %%
all_jobs = ml_client.jobs.list()
jobs_list = [
    job for job in ml_client.jobs.list() 
    if job.experiment_name == "iris-classification" 
    and job.properties.get("runSource") != "Schedule"
]
job = jobs_list[0]
job

# %%
from azure.ai.ml import Input
from datetime import datetime
from azure.ai.ml.constants import AssetTypes

job =  ml_client.jobs.get(name = "frank_airport_nl42g9wj33")

production_pipeline = ml_client.components.get(
    name="iris_production_pipeline",
    label="latest",
)

custom_job = ml_client.jobs.create_or_update(
    production_pipeline(
        data=Input(
            type=AssetTypes.MLTABLE,
            path=job.inputs.data.path
        ),
        archi=Input(
            type=AssetTypes.URI_FILE,
            path=job.inputs.archi.path
        ),
        compute="myCluster",
        lr=0.001,
        epochs=20,
    ),
    experiment_name=job.experiment_name,
    display_name = "20epochs_" + datetime.now().strftime("%Y%m%d%H%M%S")
)

# %% [markdown]
# # Deploy the model as a real-time endpoint

# %%
all_jobs = ml_client.jobs.list()
jobs_list = [
    job.name for job in ml_client.jobs.list() 
    if job.experiment_name == "iris-classification" 
    and job.properties.get("runSource") != "Schedule"
]
jobs_list
# Out:
# ['bright_onion_q4r1xc5pcb', 'frank_airport_nl42g9wj33']

# %%
all_models = ml_client.models.list(name = "iris-model")
models_list = [model for model in all_models]
models_list
# Out:
# [Model({'job_name': '409c96dd-8153-4c2d-b1f2-26bba2f0b02d', 'intellectual_property': None, 'system_metadata': None, 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'iris-model', 'description': None, 'tags': {}, 'properties': {'flavors.pytorch': '{\n  "model_data": "data",\n  "pytorch_version": "2.7.1+cu118",\n  "code": null\n}', 'flavors.python_function': '{\n  "pickle_module_name": "mlflow.pytorch.pickle_module",\n  "loader_module": "mlflow.pytorch",\n  "python_version": "3.10.18",\n  "data": "data",\n  "env": {\n    "conda": "conda.yaml",\n    "virtualenv": "python_env.yaml"\n  }\n}', 'flavors': 'pytorch,python_function', 'azureml.artifactPrefix': 'ExperimentRun/dcid.409c96dd-8153-4c2d-b1f2-26bba2f0b02d/model', 'model_json': '{"run_id": "409c96dd-8153-4c2d-b1f2-26bba2f0b02d", "artifact_path": "model", "utc_time_created": "2025-12-01 12:35:02.936314", "model_uuid": "a4310c4c0dbd43728db0d10c263a10dd", "flavors": {"pytorch": {"model_data": "data", "pytorch_version": "2.7.1+cu118", "code": null}, "python_function": {"pickle_module_name": "mlflow.pytorch.pickle_module", "loader_module": "mlflow.pytorch", "python_version": "3.10.18", "data": "data", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}}}', 'azureml.storagePath': 'ExperimentRun/dcid.409c96dd-8153-4c2d-b1f2-26bba2f0b02d/model', 'mlflow.modelSourceUri': 'azureml://francecentral.api.azureml.ms/mlflow/v2.0/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/experiments/4dd34502-067c-43ef-be41-8925824a468c/runs/409c96dd-8153-4c2d-b1f2-26bba2f0b02d/artifacts/model'}, 'print_as_yaml': False, 'id': '/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/models/iris-model/versions/4', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mylab/code/Users/alexandre.marchal/azure_iris', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7edec9cdad40>, 'serialize': <msrest.serialization.Serializer object at 0x7edeab888700>, 'version': '4', 'latest_version': None, 'path': 'azureml://subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/workspaces/alex/datastores/workspaceartifactstore/paths/ExperimentRun/dcid.409c96dd-8153-4c2d-b1f2-26bba2f0b02d/model', 'datastore': None, 'utc_time_created': None, 'flavors': {'pytorch': {'model_data': 'data', 'pytorch_version': '2.7.1+cu118', 'code': ''}, 'python_function': {'pickle_module_name': 'mlflow.pytorch.pickle_module', 'loader_module': 'mlflow.pytorch', 'python_version': '3.10.18', 'data': 'data', 'env': '{\n  "conda": "conda.yaml",\n  "virtualenv": "python_env.yaml"\n}'}}, 'arm_type': 'model_version', 'type': 'mlflow_model', 'stage': 'Development'}),
#  Model({'job_name': '8f941a8f-3c8d-43f5-8f43-8616cf569e1e', 'intellectual_property': None, 'system_metadata': None, 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'iris-model', 'description': None, 'tags': {}, 'properties': {'flavors.pytorch': '{\n  "model_data": "data",\n  "pytorch_version": "2.7.1+cu118",\n  "code": null\n}', 'flavors.python_function': '{\n  "pickle_module_name": "mlflow.pytorch.pickle_module",\n  "loader_module": "mlflow.pytorch",\n  "python_version": "3.10.18",\n  "data": "data",\n  "env": {\n    "conda": "conda.yaml",\n    "virtualenv": "python_env.yaml"\n  }\n}', 'flavors': 'pytorch,python_function', 'azureml.artifactPrefix': 'ExperimentRun/dcid.8f941a8f-3c8d-43f5-8f43-8616cf569e1e/model', 'model_json': '{"run_id": "8f941a8f-3c8d-43f5-8f43-8616cf569e1e", "artifact_path": "model", "utc_time_created": "2025-12-01 12:21:59.348032", "model_uuid": "3ebc08f5d800425294dd281a84886d25", "flavors": {"pytorch": {"model_data": "data", "pytorch_version": "2.7.1+cu118", "code": null}, "python_function": {"pickle_module_name": "mlflow.pytorch.pickle_module", "loader_module": "mlflow.pytorch", "python_version": "3.10.18", "data": "data", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}}}', 'azureml.storagePath': 'ExperimentRun/dcid.8f941a8f-3c8d-43f5-8f43-8616cf569e1e/model', 'mlflow.modelSourceUri': 'azureml://francecentral.api.azureml.ms/mlflow/v2.0/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/experiments/4dd34502-067c-43ef-be41-8925824a468c/runs/8f941a8f-3c8d-43f5-8f43-8616cf569e1e/artifacts/model'}, 'print_as_yaml': False, 'id': '/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/models/iris-model/versions/3', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mylab/code/Users/alexandre.marchal/azure_iris', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7edeab88a1d0>, 'serialize': <msrest.serialization.Serializer object at 0x7edeab8887c0>, 'version': '3', 'latest_version': None, 'path': 'azureml://subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/workspaces/alex/datastores/workspaceartifactstore/paths/ExperimentRun/dcid.8f941a8f-3c8d-43f5-8f43-8616cf569e1e/model', 'datastore': None, 'utc_time_created': None, 'flavors': {'pytorch': {'model_data': 'data', 'pytorch_version': '2.7.1+cu118', 'code': ''}, 'python_function': {'pickle_module_name': 'mlflow.pytorch.pickle_module', 'loader_module': 'mlflow.pytorch', 'python_version': '3.10.18', 'data': 'data', 'env': '{\n  "conda": "conda.yaml",\n  "virtualenv": "python_env.yaml"\n}'}}, 'arm_type': 'model_version', 'type': 'mlflow_model', 'stage': 'Development'}),
#  Model({'job_name': '0a213f9f-757b-48f4-9f93-d91e7f410dd2', 'intellectual_property': None, 'system_metadata': None, 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'iris-model', 'description': None, 'tags': {}, 'properties': {'flavors.pytorch': '{\n  "model_data": "data",\n  "pytorch_version": "2.7.1+cu118",\n  "code": null\n}', 'flavors.python_function': '{\n  "pickle_module_name": "mlflow.pytorch.pickle_module",\n  "loader_module": "mlflow.pytorch",\n  "python_version": "3.10.18",\n  "data": "data",\n  "env": {\n    "conda": "conda.yaml",\n    "virtualenv": "python_env.yaml"\n  }\n}', 'flavors': 'pytorch,python_function', 'azureml.artifactPrefix': 'ExperimentRun/dcid.0a213f9f-757b-48f4-9f93-d91e7f410dd2/model', 'model_json': '{"run_id": "0a213f9f-757b-48f4-9f93-d91e7f410dd2", "artifact_path": "model", "utc_time_created": "2025-12-01 11:51:37.689892", "model_uuid": "b8288632b712482b967bd00d9ae7db96", "flavors": {"pytorch": {"model_data": "data", "pytorch_version": "2.7.1+cu118", "code": null}, "python_function": {"pickle_module_name": "mlflow.pytorch.pickle_module", "loader_module": "mlflow.pytorch", "python_version": "3.10.18", "data": "data", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}}}', 'azureml.storagePath': 'ExperimentRun/dcid.0a213f9f-757b-48f4-9f93-d91e7f410dd2/model', 'mlflow.modelSourceUri': 'azureml://francecentral.api.azureml.ms/mlflow/v2.0/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/experiments/4dd34502-067c-43ef-be41-8925824a468c/runs/0a213f9f-757b-48f4-9f93-d91e7f410dd2/artifacts/model'}, 'print_as_yaml': False, 'id': '/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/models/iris-model/versions/2', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mylab/code/Users/alexandre.marchal/azure_iris', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7edeab88a4a0>, 'serialize': <msrest.serialization.Serializer object at 0x7edeab88a590>, 'version': '2', 'latest_version': None, 'path': 'azureml://subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/workspaces/alex/datastores/workspaceartifactstore/paths/ExperimentRun/dcid.0a213f9f-757b-48f4-9f93-d91e7f410dd2/model', 'datastore': None, 'utc_time_created': None, 'flavors': {'pytorch': {'model_data': 'data', 'pytorch_version': '2.7.1+cu118', 'code': ''}, 'python_function': {'pickle_module_name': 'mlflow.pytorch.pickle_module', 'loader_module': 'mlflow.pytorch', 'python_version': '3.10.18', 'data': 'data', 'env': '{\n  "conda": "conda.yaml",\n  "virtualenv": "python_env.yaml"\n}'}}, 'arm_type': 'model_version', 'type': 'mlflow_model', 'stage': 'Development'}),
#  Model({'job_name': '2af19801-d9fb-4be9-abed-844c3ed0b06f', 'intellectual_property': None, 'system_metadata': None, 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'iris-model', 'description': None, 'tags': {}, 'properties': {'flavors.pytorch': '{\n  "model_data": "data",\n  "pytorch_version": "2.7.1+cu118",\n  "code": null\n}', 'flavors.python_function': '{\n  "pickle_module_name": "mlflow.pytorch.pickle_module",\n  "loader_module": "mlflow.pytorch",\n  "python_version": "3.10.18",\n  "data": "data",\n  "env": {\n    "conda": "conda.yaml",\n    "virtualenv": "python_env.yaml"\n  }\n}', 'flavors': 'pytorch,python_function', 'azureml.artifactPrefix': 'ExperimentRun/dcid.2af19801-d9fb-4be9-abed-844c3ed0b06f/model', 'model_json': '{"run_id": "2af19801-d9fb-4be9-abed-844c3ed0b06f", "artifact_path": "model", "utc_time_created": "2025-12-01 11:49:41.162869", "model_uuid": "6b7a882f040d441cb90b510926fb07a5", "flavors": {"pytorch": {"model_data": "data", "pytorch_version": "2.7.1+cu118", "code": null}, "python_function": {"pickle_module_name": "mlflow.pytorch.pickle_module", "loader_module": "mlflow.pytorch", "python_version": "3.10.18", "data": "data", "env": {"conda": "conda.yaml", "virtualenv": "python_env.yaml"}}}}', 'azureml.storagePath': 'ExperimentRun/dcid.2af19801-d9fb-4be9-abed-844c3ed0b06f/model', 'mlflow.modelSourceUri': 'azureml://francecentral.api.azureml.ms/mlflow/v2.0/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/experiments/4dd34502-067c-43ef-be41-8925824a468c/runs/2af19801-d9fb-4be9-abed-844c3ed0b06f/artifacts/model'}, 'print_as_yaml': False, 'id': '/subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/providers/Microsoft.MachineLearningServices/workspaces/alex/models/iris-model/versions/1', 'Resource__source_path': '', 'base_path': '/mnt/batch/tasks/shared/LS_root/mounts/clusters/mylab/code/Users/alexandre.marchal/azure_iris', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x7edeab8886a0>, 'serialize': <msrest.serialization.Serializer object at 0x7edeaaf438b0>, 'version': '1', 'latest_version': None, 'path': 'azureml://subscriptions/2a4d20dd-fd86-4d91-a488-68362f06e683/resourceGroups/mybot/workspaces/alex/datastores/workspaceartifactstore/paths/ExperimentRun/dcid.2af19801-d9fb-4be9-abed-844c3ed0b06f/model', 'datastore': None, 'utc_time_created': None, 'flavors': {'pytorch': {'model_data': 'data', 'pytorch_version': '2.7.1+cu118', 'code': ''}, 'python_function': {'pickle_module_name': 'mlflow.pytorch.pickle_module', 'loader_module': 'mlflow.pytorch', 'python_version': '3.10.18', 'data': 'data', 'env': '{\n  "conda": "conda.yaml",\n  "virtualenv": "python_env.yaml"\n}'}}, 'arm_type': 'model_version', 'type': 'mlflow_model', 'stage': 'Development'})]

# %%
model = models_list[1]
job_child_name = model.properties.get('azureml.artifactPrefix').split('/')[1][5:]
job_child = ml_client.jobs.get(name=job_child_name)
job_child.tags["azureml.pipeline"]
# Out:
# 'bright_onion_q4r1xc5pcb'

# %%
print(f"Model: {model.name} - version: {model.version}")
# Out:
# Model: iris-model - version: 3
